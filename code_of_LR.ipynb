# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df=pd.read_csv('business_linear_regression_dataset.csv')
df.head()
# Out:
#    Advertising_Spend       Sales
# 0          21.854305   76.925304
# 1          47.782144  165.742467
# 2          37.939727  133.247850
# 3          31.939632  101.850867
# 4          12.020839   40.974576

# %%
plt.scatter(df['Advertising_Spend' ] ,df['Sales'])
plt.xlabel('Advertising_Spend')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]
x
# Out:
#     Advertising_Spend
# 0           21.854305
# 1           47.782144
# 2           37.939727
# 3           31.939632
# 4           12.020839
# ..                ...
# 95          27.220802
# 96          28.522977
# 97          24.239346
# 98           6.143861
# 99           9.855114
#
# [100 rows x 1 columns]

# %%
y
# Out:
# 0      76.925304
# 1     165.742467
# 2     133.247850
# 3     101.850867
# 4      40.974576
#          ...
# 95     91.193755
# 96     99.444912
# 97     86.543470
# 98     22.886966
# 99     38.628816
# Name: Sales, Length: 100, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([ 28.09746019, 157.35416749, 138.2934052 , 121.23230089,
#         58.4531035 ,  86.65530244,  63.64108355, 152.42131179,
#         21.41531624,  76.4530219 ,  85.37909557, 112.68368198,
#        145.01330341, 165.75984992,  36.81066297,  42.47440997,
#        138.14188908,  29.72800915, 147.65376708,  44.7299145 ])

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
r2_score(y_test,y_pred)
# Out:
# 0.993073076905515

# %%
r2 = r2_score(y_test, y_pred)  
mae = mean_absolute_error(y_test, y_pred)  
mse = mean_squared_error(y_test, y_pred)  


print(f'Mean Absolute Error: {mae}')
print(f'R-squared: {r2}')
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Absolute Error: 2.9567128895948946
# R-squared: 0.993073076905515
# Mean Squared Error: 16.342487842925074

# %%
plt.scatter(df['Advertising_Spend'],df['Sales'])
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('Advertising_Spend')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')
